# %%
class computer:
    def config(self):
        print("i5","16gb","1TB")
              
com1=computer()
com2=computer()
computer.config(com1)
computer.config(com2)
com1.config()
com2.config()
# Out:
# i5 16gb 1TB
# i5 16gb 1TB
# i5 16gb 1TB
# i5 16gb 1TB
